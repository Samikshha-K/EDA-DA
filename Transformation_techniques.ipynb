# %% [markdown]
# <a href="https://colab.research.google.com/github/Samikshha-K/EDA-DA/blob/main/Transformation_techniques.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
data=pd.read_csv('https://raw.githubusercontent.com/salemprakash/EDA/main/Data/Benefits.csv')

# %%
data.head()
# Out:
#    rownames  stateur  statemb  state  age  tenure     joblost nwhite school12  \
# 0         1      4.5      167     42   49      21       other     no       no
# 1         2     10.5      251     55   26       2  slack_work     no       no
# 2         3      7.2      260     21   40      19       other     no      yes
# 3         4      5.8      245     56   51      17  slack_work    yes       no
# 4         5      6.5      125     58   33       1  slack_work     no      yes
#
#       sex bluecol smsa married dkids dykids  yrdispl        rr head   ui
# 0    male     yes  yes      no    no     no        7  0.290631  yes  yes
# 1    male     yes  yes      no   yes    yes       10  0.520202  yes   no
# 2  female     yes  yes     yes    no     no       10  0.432490  yes  yes
# 3  female     yes  yes     yes    no     no       10  0.500000   no  yes
# 4    male     yes  yes     yes   yes    yes        4  0.390625  yes   no

# %% [markdown]
# Data Deduplication

# %%
data.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 4872    False
# 4873    False
# 4874    False
# 4875    False
# 4876    False
# Length: 4877, dtype: bool

# %%
data_no_dup = data.drop_duplicates()
data_no_dup
# Out:
#       rownames  stateur  statemb  state  age  tenure     joblost nwhite  \
# 0            1      4.5      167     42   49      21       other     no
# 1            2     10.5      251     55   26       2  slack_work     no
# 2            3      7.2      260     21   40      19       other     no
# 3            4      5.8      245     56   51      17  slack_work    yes
# 4            5      6.5      125     58   33       1  slack_work     no
# ...        ...      ...      ...    ...  ...     ...         ...    ...
# 4872      4873      7.4      168     33   35      12  slack_work    yes
# 4873      4874      7.0      189     74   39       5  slack_work     no
# 4874      4875      8.0      168     74   59      13  slack_work     no
# 4875      4876      6.3      191     41   33      11  slack_work     no
# 4876      4877      9.3      188     94   27       2       other     no
#
#      school12     sex bluecol smsa married dkids dykids  yrdispl        rr  \
# ...

# %%
data_col_dup = data.drop_duplicates(['age'])
data_col_dup
# Out:
#      rownames  stateur  statemb  state  age  tenure             joblost  \
# 0           1      4.5      167     42   49      21               other
# 1           2     10.5      251     55   26       2          slack_work
# 2           3      7.2      260     21   40      19               other
# 3           4      5.8      245     56   51      17          slack_work
# 4           5      6.5      125     58   33       1          slack_work
# 6           7      5.8      166     93   30       5  position_abolished
# 8           9      7.7      213     84   54      20               other
# 9          10      6.0      187     33   31       1          slack_work
# 10         11      7.1      206     33   56      20          slack_work
# 12         13      5.0      279     22   21       1          slack_work
# 13         14      6.6      291     22   35       1          slack_work
# 14         15      7.2      166     93   23       1          slack_work
# ...

# %% [markdown]
# Replacing Values

# %%
replacedData=data.replace(to_replace =[49,245,10], value= [np.nan,np.nan,np.nan])
replacedData
# Out:
#       rownames  stateur  statemb  state   age  tenure     joblost nwhite  \
# 0          1.0      4.5    167.0     42   NaN    21.0       other     no
# 1          2.0     10.5    251.0     55  26.0     2.0  slack_work     no
# 2          3.0      7.2    260.0     21  40.0    19.0       other     no
# 3          4.0      5.8      NaN     56  51.0    17.0  slack_work    yes
# 4          5.0      6.5    125.0     58  33.0     1.0  slack_work     no
# ...        ...      ...      ...    ...   ...     ...         ...    ...
# 4872    4873.0      7.4    168.0     33  35.0    12.0  slack_work    yes
# 4873    4874.0      7.0    189.0     74  39.0     5.0  slack_work     no
# 4874    4875.0      8.0    168.0     74  59.0    13.0  slack_work     no
# 4875    4876.0      6.3    191.0     41  33.0    11.0  slack_work     no
# 4876    4877.0      9.3    188.0     94  27.0     2.0       other     no
#
#      school12     sex bluecol smsa married dkids dykids  yrdispl        rr  \
# ...

# %% [markdown]
# Handling missing data

# %%
data.isnull()
# Out:
#       rownames  stateur  statemb  state    age  tenure  joblost  nwhite  \
# 0        False    False    False  False  False   False    False   False
# 1        False    False    False  False  False   False    False   False
# 2        False    False    False  False  False   False    False   False
# 3        False    False    False  False  False   False    False   False
# 4        False    False    False  False  False   False    False   False
# ...        ...      ...      ...    ...    ...     ...      ...     ...
# 4872     False    False    False  False  False   False    False   False
# 4873     False    False    False  False  False   False    False   False
# 4874     False    False    False  False  False   False    False   False
# 4875     False    False    False  False  False   False    False   False
# 4876     False    False    False  False  False   False    False   False
#
#       school12    sex  bluecol   smsa  married  dkids  dykids  yrdispl     rr  \
# ...

# %%
replacedData.isnull()
# Out:
#       rownames  stateur  statemb  state    age  tenure  joblost  nwhite  \
# 0        False    False    False  False   True   False    False   False
# 1        False    False    False  False  False   False    False   False
# 2        False    False    False  False  False   False    False   False
# 3        False    False     True  False  False   False    False   False
# 4        False    False    False  False  False   False    False   False
# ...        ...      ...      ...    ...    ...     ...      ...     ...
# 4872     False    False    False  False  False   False    False   False
# 4873     False    False    False  False  False   False    False   False
# 4874     False    False    False  False  False   False    False   False
# 4875     False    False    False  False  False   False    False   False
# 4876     False    False    False  False  False   False    False   False
#
#       school12    sex  bluecol   smsa  married  dkids  dykids  yrdispl     rr  \
# ...

# %%
replacedData.isnull().sum()
# Out:
# rownames      3
# stateur      39
# statemb      51
# state         0
# age          67
# tenure      136
# joblost       0
# nwhite        0
# school12      0
# sex           0
# bluecol       0
# smsa          0
# married       0
# dkids         0
# dykids        0
# yrdispl     648
# rr            0
# head          0
# ui            0
# dtype: int64

# %%
replacedData.count()
# Out:
# rownames    4874
# stateur     4838
# statemb     4826
# state       4877
# age         4810
# tenure      4741
# joblost     4877
# nwhite      4877
# school12    4877
# sex         4877
# bluecol     4877
# smsa        4877
# married     4877
# dkids       4877
# dykids      4877
# yrdispl     4229
# rr          4877
# head        4877
# ui          4877
# dtype: int64

# %% [markdown]
# Droping missing values

# %%
replacedData.dropna()
# Out:
#       rownames  stateur  statemb  state   age  tenure             joblost  \
# 4          5.0      6.5    125.0     58  33.0     1.0          slack_work
# 6          7.0      5.8    166.0     93  30.0     5.0  position_abolished
# 7          8.0      5.8    214.0     84  26.0     3.0          slack_work
# 8          9.0      7.7    213.0     84  54.0    20.0               other
# 11        12.0     10.1    132.0     12  54.0    26.0               other
# ...        ...      ...      ...    ...   ...     ...                 ...
# 4872    4873.0      7.4    168.0     33  35.0    12.0          slack_work
# 4873    4874.0      7.0    189.0     74  39.0     5.0          slack_work
# 4874    4875.0      8.0    168.0     74  59.0    13.0          slack_work
# 4875    4876.0      6.3    191.0     41  33.0    11.0          slack_work
# 4876    4877.0      9.3    188.0     94  27.0     2.0               other
#
#      nwhite school12     sex bluecol smsa married dkids dykids  yrdispl  \
# ...

# %%
replacedData.dropna(how='all')
# Out:
#       rownames  stateur  statemb  state   age  tenure     joblost nwhite  \
# 0          1.0      4.5    167.0     42   NaN    21.0       other     no
# 1          2.0     10.5    251.0     55  26.0     2.0  slack_work     no
# 2          3.0      7.2    260.0     21  40.0    19.0       other     no
# 3          4.0      5.8      NaN     56  51.0    17.0  slack_work    yes
# 4          5.0      6.5    125.0     58  33.0     1.0  slack_work     no
# ...        ...      ...      ...    ...   ...     ...         ...    ...
# 4872    4873.0      7.4    168.0     33  35.0    12.0  slack_work    yes
# 4873    4874.0      7.0    189.0     74  39.0     5.0  slack_work     no
# 4874    4875.0      8.0    168.0     74  59.0    13.0  slack_work     no
# 4875    4876.0      6.3    191.0     41  33.0    11.0  slack_work     no
# 4876    4877.0      9.3    188.0     94  27.0     2.0       other     no
#
#      school12     sex bluecol smsa married dkids dykids  yrdispl        rr  \
# ...

# %% [markdown]
# Filling missing values

# %%
filledData=replacedData.fillna(0)
filledData
# Out:
#       rownames  stateur  statemb  state   age  tenure     joblost nwhite  \
# 0          1.0      4.5    167.0     42   0.0    21.0       other     no
# 1          2.0     10.5    251.0     55  26.0     2.0  slack_work     no
# 2          3.0      7.2    260.0     21  40.0    19.0       other     no
# 3          4.0      5.8      0.0     56  51.0    17.0  slack_work    yes
# 4          5.0      6.5    125.0     58  33.0     1.0  slack_work     no
# ...        ...      ...      ...    ...   ...     ...         ...    ...
# 4872    4873.0      7.4    168.0     33  35.0    12.0  slack_work    yes
# 4873    4874.0      7.0    189.0     74  39.0     5.0  slack_work     no
# 4874    4875.0      8.0    168.0     74  59.0    13.0  slack_work     no
# 4875    4876.0      6.3    191.0     41  33.0    11.0  slack_work     no
# 4876    4877.0      9.3    188.0     94  27.0     2.0       other     no
#
#      school12     sex bluecol smsa married dkids dykids  yrdispl        rr  \
# ...
