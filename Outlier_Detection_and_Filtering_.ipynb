# %% [markdown]
# <a href="https://colab.research.google.com/github/Samikshha-K/EDA-DA/blob/main/Outlier_Detection_and_Filtering_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
data=pd.read_csv('https://raw.githubusercontent.com/salemprakash/EDA/main/Data/Benefits.csv')

# %%
data.head()
# Out:
#    rownames  stateur  statemb  state  age  tenure     joblost nwhite school12  \
# 0         1      4.5      167     42   49      21       other     no       no
# 1         2     10.5      251     55   26       2  slack_work     no       no
# 2         3      7.2      260     21   40      19       other     no      yes
# 3         4      5.8      245     56   51      17  slack_work    yes       no
# 4         5      6.5      125     58   33       1  slack_work     no      yes
#
#       sex bluecol smsa married dkids dykids  yrdispl        rr head   ui
# 0    male     yes  yes      no    no     no        7  0.290631  yes  yes
# 1    male     yes  yes      no   yes    yes       10  0.520202  yes   no
# 2  female     yes  yes     yes    no     no       10  0.432490  yes  yes
# 3  female     yes  yes     yes    no     no       10  0.500000   no  yes
# 4    male     yes  yes     yes   yes    yes        4  0.390625  yes   no

# %%
tenure = data["tenure"]
tenure[np.abs(tenure) > 35]
# Out:
# 158     39
# 257     38
# 654     38
# 738     36
# 990     37
# 1193    40
# 2444    40
# 2494    41
# 2606    40
# 2729    38
# 3242    37
# 3243    40
# 3564    40
# 3633    39
# 3676    36
# 4291    40
# 4352    37
# Name: tenure, dtype: int64

# %%
age = data["age"]
data[np.abs(age) > 60]
# Out:
#       rownames  stateur  statemb  state  age  tenure             joblost  \
# 47          48      9.0      282     14   61      27          slack_work
# 58          59      7.4      168     33   61      25               other
# 86          87      7.4      213     84   61       1          slack_work
# 158        159      9.2      276     34   61      39          slack_work
# 229        230      8.1      147     31   61      22               other
# 435        436      5.9      182     74   61       2          slack_work
# 540        541      5.1      225     51   61       9               other
# 692        693      6.5      166     87   61       1  position_abolished
# 703        704      4.9      202     87   61      10               other
# 705        706      5.3      166     93   61      13  seasonal_job_ended
# 1221      1222      5.3      166     93   61       8          slack_work
# 1241      1242      6.3      191     41   61      16               other
# ...
